# %%
t_omp=[0.0254143,0.123319,0.819705,5.59746]
t_seq=[0.000676715,0.00429273,0.0482545,0.448568]

# %%
import matplotlib.pyplot as plt
# num_files = [100, 1000, 10000, 100000]
num_files = [1, 2, 3, 4]

seql, = plt.plot(num_files, t_seq, 'ro-', label='sequencial')
ompl, = plt.plot(num_files, t_omp, 'co-', label= 'omp')
plt.xlabel('Quantidade de arquivos')
plt.ylabel('Tempo de simulação')
plt.title("Avaliacao desempenho")
plt.legend(handles=[seql,ompl])
plt.show()

# %%
t_omp=[0.0638635,0.503051,2.15181,3.89439]
t_seq=[0.0412588,0.362404,3.13983,10.9799]

# %%
import matplotlib.pyplot as plt
# num_files = [1, 10, 50, 100] megas
num_files = [1, 2, 3, 4]

seql, = plt.plot(num_files, t_seq, 'ro-', label='sequencial')
ompl, = plt.plot(num_files, t_omp, 'co-', label= 'omp')
plt.xlabel('Quantidade de arquivos')
plt.ylabel('Tempo de simulação')
plt.title("Avaliacao desempenho")
plt.legend(handles=[seql,ompl])
plt.show()
